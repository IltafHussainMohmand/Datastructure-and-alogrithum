# %% [markdown]
# ## Create an Empty List

# %%
a = []
print(a)
# Out:
# []

# %%
a = []
print(a)
# Out:
# []

# %% [markdown]
# ### Check if a List is Empty

# %%
# Out:
# [2]

# %%
a = []
if not a:
    print(a)
else:
    print("not empty")
# Out:
# []

# %% [markdown]
# ## creating python list

# %%
cars = ["Ford", "Volvo", "BMW"]
print(cars)
# Out:
# ['Ford', 'Volvo', 'BMW']
